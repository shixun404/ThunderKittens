# %%
import matplotlib.pyplot as plt

# 你的颜色定义
labels = [
    "0 Comm. SMs",
    "2 Comm. SMs",
    "4 Comm. SMs",
    "8 Comm. SMs",
    "16 Comm. SMs",
]

colors = [
    "#F29441",
    "#9467BD",
    "#4EAE4E",
    "#67BBBD",
    "#E67C7C",
]

# 每个 bar 的高度随便设成 1
values = [1] * len(colors)
x = range(len(colors))

fig, ax = plt.subplots(figsize=(8, 2.5))

bars = ax.bar(x, values, color=colors, edgecolor="black", linewidth=0.6)

# 标注颜色 hex
for i, bar in enumerate(bars):
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height() / 2,
        colors[i],
        ha="center",
        va="center",
        fontsize=10,
        color="black",
        fontweight="bold"
    )

ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=0)
ax.set_yticks([])
ax.set_ylim(0, 1)

ax.set_title("Visualization of Comm. SMs Color Palette", pad=10)

# 去掉多余边框，论文/slide 风格
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_visible(False)

plt.tight_layout()
plt.show()
